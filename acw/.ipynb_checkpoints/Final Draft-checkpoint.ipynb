# %% [markdown]
# <br></br>
# # Data Mining and Decision Systems ACW
# <br></br>
# #### Student number: 201601628
# <br>
# <hr>

# %% [markdown]
# <a id="0"></a>
# <h1>Contents</h1>
# <hr>
# <div style="line-height: 2.5">
# <div><a href="#0"><h2 style="display: inline">.... 0. Notebook Initialisation</h2></a></div>
# <div><a href="#01">........ <h3 style="display: inline">0.1. Package Imports</h3></a></div>
# <div><a href="#02">........ <h3 style="display: inline">0.2. Data Loading</h3></a></div>
# <div><a href="#03">........ <h3 style="display: inline">0.3. Misc</h3></a></div>
# <p></p>
# <div><a href="#1"><h2 style="display: inline">.... 1. CRISP DM</h2></a></div>
# <div><a href="#11">........ <h3 style="display: inline">1.1. Business Understanding</h3></a></div>
# <!--  -->
# <div><a href="#12">........ <h3 style="display: inline">1.2. Data Understanding</h3></a></div>
# <div><a href="#121">............ <h4 style="display: inline">1.2.1. Data Dictionary</h4></a></div>
# <div><a href="#122">............ <h4 style="display: inline">1.2.2. Data Correctness</h4></a></div>
# <div><a href="#1221">................ <h5 style="display: inline">1.2.2.1. Checking for Missing Data</h5></a></div>
# <div><a href="#1222">................ <h5 style="display: inline">1.2.2.2. Checking for Duplicated Data</h5></a></div>
# <div><a href="#1223">................ <h5 style="display: inline">1.2.2.3. Checking for Corrupt Data</h5></a></div>
# <div><a href="#123">............ <h4 style="display: inline">1.2.3. Data Distribution</h4></a></div>
# <div><a href="#124">............ <h4 style="display: inline">1.2.4. Feature Inspection</h4></a></div>
# <div><a href="#125">............ <h4 style="display: inline">1.2.5. Evaluation of Understanding</h4></a></div>
# <div><a href="#126">............ <h4 style="display: inline">1.2.6. Actions</h4></a></div>
# <!--  -->
# <div style="line-height:2.5;"><a href="#13">........ <h3 style="display: inline">1.3. Data Preparation</h3></a></div>
# <div><a href="#131">............ <h4 style="display: inline">1.3.1. Cleaning</h4></a></div>
# <div><a href="#132">............ <h4 style="display: inline">1.3.2. Transformation</h4></a></div>
# <div><a href="#133">............ <h4 style="display: inline">1.3.3. Stratification (TTS)</h4></a></div>
# <!--  -->
# <div style="line-height:2.5;"><a href="#14">........ <h3 style="display: inline">1.4. Modeling</h3></a></div>
# <div><a href="#141">............ <h4 style="display: inline">1.4.1. Baseline Models (all features)</h4></a></div>
# <div><a href="#142">............ <h4 style="display: inline">1.4.2. Baseline Models (selected features)</h4></a></div>
# <div><a href="#143">............ <h4 style="display: inline">1.4.3. Model Selection</h4></a></div>
# <div><a href="#144">............ <h4 style="display: inline">1.4.4. Hyperparemeter Tuning</h4></a></div>
# <!--  -->
# <div style="line-height:2.5;"><a href="#15">........ <h3 style="display: inline">1.5. Evaluation</h3></a></div>
# <!--  -->
# <div style="line-height:2.5;"><a href="#16">........ <h3 style="display: inline">1.6. (Theoretical) Deployment</h3></a></div>
# </div>
#
# <!--  Data Understanding
# Data dictionary
# 	Data assumptions
# 		Data conformity
# 			Cols exist
# 			Number of categories
# 			Category correctness
# 			Data types
#
# 		Missing data
#
# 		Duplicated data
# 			Duplicated records
# 			Duplicated attributes
#
# 		Data distribution/balance/outliers
#
# 		Data correlations and feature inspection
# 			Univariate
# 			Covariate (with label)
# 			Multivariate (with label)
# 			Apriori
#
# 		Inspect and understand concerns
#
# 		Actions
#
# Data prep
# 	Clean according to understanding
# 	Normalise and Encode
# 	TTS
# 		Compare with raw data
#
#
# Modeling
# 	Baseline model all features & all models
# 		kfold
# 		multi-linear?
# 		dtree
# 		dnn
# 	Baseline model selected features
# 		kfold
# 		dtree
# 		dnn
# 	Select best model
# 		tune hyperparams
#
# Data prep2
# 	impute missing data
# 	better or worse performance ? -->

# %% [markdown]
# <a id="0"></a>
# <h2>0. Notebook Initialisation</h2>

# %% [markdown]
# <a id="01"></a>
# <h3>0.1. Package Imports</h3>

# %%
## Import all libraries for use in notebook.
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import pandas as pd
import numpy as np

from sklearn import model_selection, linear_model
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse
from sklearn.preprocessing import MinMaxScaler

from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from collections import defaultdict ## Used in automating and collating data discrepancies.
from datetime import date ## Used to check the correct data is being loaded after the deadline.

# %matplotlib inline

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="02"></a>
# <h3>0.2. Data Loading</h3>

# %%
deadline = date(day=12,month=12, year=2019)
path = "data.csv" ## Relative path to train/test data.
## Failsafe incase I forget to swap in the orginal csv for submission after testing on modified versions.
if (deadline < date.today()):
    path = "data.csv" ## Relative path to train/test data.
    print("Forgot to change data input to default acw csv; switched to correct dataset.")

rawData = pd.read_csv(path) ## Will reamin untouched for reference.
rawData.columns = [col.lower() for col in rawData.columns] ## Make headers lowercase to avoid some trivial errors.

rawData ## Show
# Out:
#         random      id indication diabetes  ihd hypertension arrhythmia  \
# 0     0.602437  218242        A-F       no   no          yes         no
# 1     0.602437  159284        TIA       no   no           no         no
# 2     0.602437  106066        A-F       no  yes          yes         no
# 3     0.128157  229592        TIA       no   no          yes         no
# 4     0.676862  245829        CVA       no   no           no         no
# ...        ...     ...        ...      ...  ...          ...        ...
# 1515  0.391440   93406        A-F       no  yes           no         no
# 1516  0.253504  121814        A-F       no   no          yes        yes
# 1517  0.620373  101754        TIA       no   no          yes         no
# 1518  0.639342  263836        A-F       no  yes           no         no
# 1519  0.634922  254941        CVA       no   no           no         no
#
#      history  ipsi contra   label
# 0         no  78.0    20   NoRisk
# 1         no  70.0    60   NoRisk
# 2         no  95.0     40    Risk
# 3         no  90.0     85    Risk
# 4         no  70.0    20   NoRisk
# ...      ...   ...    ...     ...
# 1515      no  76.0    60   NoRisk
# 1516      no  90.0     75    Risk
# 1517      no  75.0    20   NoRisk
# 1518      no  70.0    45   NoRisk
# 1519      no  60.0    20   NoRisk
#
# [1520 rows x 11 columns]

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="03"></a>
# <h3>0.3. Misc</h3>
# Define some variables for easy access to properties of the raw data.

# %%
rawNRows = rawData.shape[0]
rawNCols = rawData.shape[1]
rawColNames = rawData.columns.values # Often used as an iterator.
concerns = defaultdict(list) ## Dict for storing data discrepencies to output at the end of checks.

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="1"></a>
# <h2>1. CRISP DM</h2>
# <img src="crisp-dm.png" style="max-height:300px">
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="11"></a>
# <h3>1.1. Business Understanding</h3>

# %% [markdown]
# <div style="font-size: 14px">
# <p>DOMAIN: Cardio-vascular medicine / healthcare</p>
# <p>PROBLEM TYPE: Classification</p>
# <p>INPUTS: Tabulated patient data</p>
# <p>OUTPUTS:</p>
#     <ul>
#         <li>Risk</li>
#         <li>No Risk</li>
#     </ul>
# </div>

# %% [markdown]
# <a id="12"></a>
# <h3>1.2. Data Understanding</h3>
# Inspect a copy (for safety) of the raw data, as-is.

# %%
df = rawData.copy()

# %% [markdown]
# <a id="121"></a>
# <h4>1.2.1. Data Dictionary</h4>

# %% [markdown]
# <table>
#     <tbody>
#         <tr>
#             <td>
#                 <p><strong>Attribute</strong></p>
#             </td>
#             <td>
#                 <p><strong>Value Type</strong></p>
#             </td>
#             <td>
#                 <p><strong>NumberOfValues</strong></p>
#             </td>
#             <td>
#                 <p><strong>Values</strong></p>
#             </td>
#             <td>
#                 <p><strong>Comment</strong></p>
#             </td>
#             <td>
#                 <p><strong>Non-clinical Description</strong></p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Random</p>
#             </td>
#             <td>
#                 <p>Real</p>
#             </td>
#             <td>
#                 <p>Number of Records</p>
#             </td>
#             <td>
#                 <p>Unique</p>
#             </td>
#             <td>
#                 <p>Real number of help in randomly sorting the data records</p>
#             </td>
#             <td>
#                 <p>Real number of&nbsp;help&nbsp;in randomly sorting the data records: Should be unique values.</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Id</p>
#             </td>
#             <td>
#                 <p>Integer</p>
#             </td>
#             <td>
#                 <p>Max of Number of Records</p>
#             </td>
#             <td>
#                 <p>Unique to patient</p>
#             </td>
#             <td>
#                 <p>Anonymous patient record identifier: Should be unique values unless patient has multiple sessions</p>
#             </td>
#             <td>
#                 <p>Anonymous patient record identifier: Should be unique value per patient. Patient can have multiple sessions</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Indication</p>
#             </td>
#             <td>
#                 <p>Nominal</p>
#             </td>
#             <td>
#                 <p>Four</p>
#             </td>
#             <td>
#                 <p>{a-f, asx, cva, tia}</p>
#             </td>
#             <td>
#                 <p>What type of Cardiovascular event triggered the hospitalisation?</p>
#             </td>
#             <td>
#                 <p>What type of Cardiovascular event triggered the hospitalisation?</p><p> a-f :&nbsp;Atrial-Fibrillation</p>
#                 <p>asx&nbsp;:&nbsp;Asymptomatic Stenosis&nbsp;</p><p>cva&nbsp;: Cardiovascular Arrest</p>
#                 <p>tia&nbsp;:&nbsp;Transient Ischemic Attack ("mini-heart attack")</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Diabetes</p>
#             </td>
#             <td>
#                 <p>Nominal</p>
#             </td>
#             <td>
#                 <p>Two</p>
#             </td>
#             <td>
#                 <p>{no, yes}</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from Diabetes?</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from Diabetes?</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>IHD</p>
#             </td>
#             <td>
#                 <p>Nominal</p>
#             </td>
#             <td>
#                 <p>Two</p>
#             </td>
#             <td>
#                 <p>{no, yes}</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from Coronary artery disease (CAD), also known as ischemic heart disease (IHD)?</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from Coronary artery disease (CAD), also known as ischemic heart disease (IHD)?</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Hypertension</p>
#             </td>
#             <td>
#                 <p>Nominal</p>
#             </td>
#             <td>
#                 <p>Two</p>
#             </td>
#             <td>
#                 <p>{no, yes}</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from Hypertension?</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from Hypertension?</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Arrhythmia</p>
#             </td>
#             <td>
#                 <p>Nominal</p>
#             </td>
#             <td>
#                 <p>Two</p>
#             </td>
#             <td>
#                 <p>{no, yes}</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from</p>
#                 <p>Arrhythmia (i.e. erratic heart beat)?</p>
#             </td>
#             <td>
#                 <p>Does the patient suffer from Arrhythmia (i.e. erratic&nbsp;heart beat)?</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>History</p>
#             </td>
#             <td>
#                 <p>Nominal</p>
#             </td>
#             <td>
#                 <p>Two</p>
#             </td>
#             <td>
#                 <p>{no, yes}</p>
#             </td>
#             <td>
#                 <p>Has the patient a history of</p>
#                 <p>Cardiovascular interventions?</p>
#             </td>
#             <td>
#                 <p>Has the patient a history of Cardiovascular interventions?</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>IPSI</p>
#             </td>
#             <td>
#                 <p>Integer</p>
#             </td>
#             <td>
#                 <p>Potentially 101</p>
#             </td>
#             <td>
#                 <p>[0, 100]</p>
#             </td>
#             <td>
#                 <p>Percentage figure for cerebral ischemic lesions defined as ipsilateral</p>
#             </td>
#             <td>
#                 <p>Percentage figure for cerebral ischemic lesions defined as ipsilateral</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Contra</p>
#             </td>
#             <td>
#                 <p>Integer</p>
#             </td>
#             <td>
#                 <p>Potentially 101</p>
#             </td>
#             <td>
#                 <p>[0, 100]</p>
#             </td>
#             <td>
#                 <p>Percentage figure for contralateral cerebral ischemic lesions</p>
#             </td>
#             <td>
#                 <p>Percentage figure for contralateral cerebral ischemic lesions</p>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <p>Label</p>
#             </td>
#             <td>
#                 <p>Nominal</p>
#             </td>
#             <td>
#                 <p>Two</p>
#             </td>
#             <td>
#                 <p>{risk, norisk}</p>
#             </td>
#             <td>
#                 <p>Is the patient at risk (Mortality)?</p>
#             </td>
#             <td>
#                 <p>Is the patient at risk (Mortality)?</p>
#             </td>
#         </tr>
#     </tbody>

# %% [markdown]
# <br>
# <b style="color: red;">NOTE:</b>
# <p style="font-size: 14px">"Session" is also included in the non-clinical description, but not included in the data dictionary.</p>
# <br>
# <table>
#     <tr>
#         <td>
#             <p><strong>Attribute</strong></p>
#         </td>
#         <td>
#             <p><strong>Value Type</strong></p>
#         </td>
#         <td>
#             <p><strong>NumberOfValues</strong></p>
#         </td>
#         <td>
#             <p><strong>Values</strong></p>
#         </td>
#         <td>
#             <p><strong>Comment</strong></p>
#         </td>
#         <td>
#             <p><strong>Non-clinical Description</strong></p>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <p>Session</p>
#         </td>
#         <td>
#             <p>Unknown</p>
#         </td>
#         <td>
#             <p>Max Number of Records (assumed)</p>
#         </td>
#         <td>
#             <p>Unique to patient</p>
#         </td>
#         <td>
#             <p>Unknown</p>
#         </td>
#         <td>
#             <p>Anonymous patient session identifier.</p>
#         </td>
#     </tr>
# </table>
# <br>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="122"></a>
# <h4>1.2.2. Data Correctness</h4>
# Check for data conformity to data dictionary and explore common pitfalls (e.g. missing or duplicate data).

# %% [markdown]
# <a id="1221"></a>
# <h5>1.2.2.1 Checking for Missing Data</h5>
# Look for records containing nan or missing values.

# %%
concerns["Missing Data"] = ["The following features have missing data:"] ## Init list for missing data concerns.

for col in rawColNames:
    nans = df[col][df[col].isna() == True]
    indexes = nans.index.values
    nNans = len(nans)
    
    if (nNans > 0):
        concernStr = ("    " + col.upper() + " has " + str(nNans) + " nan values (at indexes: " + str(indexes) + ").")
        concerns["Missing Data"].append(concernStr)
# concerns["Missing Data"]

df = df.dropna() ## Ignore nan values for rest of checks in this phase.

# %% [markdown]
# <!-- <a href="#0">[back to top]</a> -->

# %% [markdown]
# <a id="1222"></a>
# <h5>1.2.2.2 Checking for Duplicated Data</h5>
# Look for records that are entirely the same or very similiar (e.g. allow different values for random or id).

# %%
## Helper function for checking for duplicates when any number of columns are dropped.
def CheckForDuplicates(ignore=[]):
    dupes = df.drop(columns=ignore)[df.drop(columns=ignore).duplicated() == True]
    if dupes.shape[0] > 0:
        return dupes
    else:
        return 0 # "No duplicates."

# %% [markdown]
# Check for records that are complete duplicates.

# %%
concerns["Duplicated Data"] = ["The records at the following indexes are duplicates:"] ## Init list for duplicated data concerns.
returnVal = CheckForDuplicates(ignore=[col])
if (type(returnVal) != int):
    concerns["Duplicated Data"].append(("Complete records:", returnVal))
#     print(returnVal)

## dupes = df[df.duplicated() == True]
## indexes = dupes.index.values
## nDupes = len(dupes)

## if (nDupes > 0):
##     concerns["Duplicated Data"].append(dupes)#str(dupes.index.values))
## concerns["Duplicated Data"]

# %% [markdown]
# Check for records that are duplicates if when a single column is removed.

# %%
for col in rawColNames:
    returnVal = CheckForDuplicates(ignore=[col])
    if (type(returnVal) != int):
        colsIgnored = ("Ignoring column " + col + ":")
        concerns["Duplicated Data"].append((colsIngored, returnVal))
#         print(returnVal)

# %% [markdown]
# Check for records that are duplicates if a pair of features are ignored.

# %%
i = 0
for colO in rawColNames:
    i+=1
    for colI in rawColNames[i:]:
        returnVal = CheckForDuplicates(ignore=[colI, colO])
        if (type(returnVal) != int):
            colsIgnored = ("When ignoring columns " + colI + " and " + colO + ":")
            concerns["Duplicated Data"].append((colsIgnored, returnVal))
#             print(returnVal)

# %%
i = 0
j = 1
for colO in rawColNames:
    i += 1
    for colI in rawColNames[i:]:
        j += 1
        for colIM in rawColNames[j:]:
            returnVal = CheckForDuplicates(ignore=[colI, colO, colIM])
            if (type(returnVal) != int):
                colsIgnored = ("When ignoring columns " + colI + " and " + colO + " and " + colIM + ":")
                concerns["Duplicated Data"].append((colsIgnored, returnVal))

#                 print(returnVal)

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="1223"></a>
# <h5>1.2.2.3 Checking for Corrupted Data</h5>
# Create an object that defines a set of assumptions as described in the data dictionary and flag any concerns.

# %%
# Dict derived from data dictionary for automated checking.
## key == column name.
## - valType == python data type.
## - nVals == range of accepted values for continuous column.
## - vals == possible values for any categoric or discrete column.

dataAssumptions = {
    "random":{ ## Col name.
        "valType": float, ## Real.
        "nVals": (rawNRows, rawNRows), # Unique per record.
    },  
    "id":{
        "valType": int,## Integer.
        "nVals": (1, rawNRows), ## Unique per patient.
    },
    "indication":{
        "valType": str, ## Nominal.
        "vals": ["a-f","asx","cva","tia"] ## Possible values (except nan).
    },
    "diabetes":{
        "valType": str, ## Nominal.
        "vals": ["yes", "no"]
    },
    "ihd":{
        "valType": str, ## Nominal.
        "vals": ["yes", "no"]
    },
    "hypertension":{
        "valType": str, ## Nominal.
        "vals": ["yes", "no"]
    },
    "arrhythmia":{
        "valType": str, ## Nominal.
        "vals": ["yes", "no"]
    },
    "history": {
        "valType": str, ## Nominal.
        "vals": ["yes", "no"]
    },
    "ipsi": {
        "valType": int, ## Integer.
        "vals": np.arange(0,101) # Percentage.
    },
    "contra": {
        "valType": int, ## Integer.
        "vals": np.arange(0,101), # Percentage.
    },
    "label": {
        "valType": str, ## Nominal.
        "vals": ["risk", "norisk"]
    },
    "session":{
        "valType": object, # Unknown.
        "nVals": (1, rawNRows), ## Unique per patient (assumed).
    },
}

# %%
## Check for all expected columns exist in the data.
missingCols = []
for k, v in dataAssumptions.items(): ## k = key, v == value.
    if (k not in rawColNames):
        missingCols.append(k)
if (len(missingCols) > 0):
    print("The following expected columns are missing from the data:")
    print(missingCols)
else:
    print("No concerns.")
# Out:
# The following expected columns are missing from the data:
# ['session']

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="123"></a>
# <h4>1.2.3. Data Distribution</h4>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="124"></a>
# <h4>1.2.4. Feature Inspection</h4>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="125"></a>
# <h4>1.2.5. Evaluation of Understanding</h4>
# Output collated concerns and evaluate.

# %%
concerns
# Out:
# defaultdict(list,
#             {'Missing Data': ['The following features have missing data:',
#               '    INDICATION has 3 nan values (at indexes: [ 442  822 1007]).',
#               '    DIABETES has 2 nan values (at indexes: [447 514]).',
#               '    HYPERTENSION has 3 nan values (at indexes: [201 590 983]).',
#               '    HISTORY has 2 nan values (at indexes: [337 784]).',
#               '    IPSI has 4 nan values (at indexes: [620 752 845 916]).',
#               '    LABEL has 3 nan values (at indexes: [ 812  974 1418]).'],
#              'Duplicated Data': ['The records at the following indexes are duplicates:',
#               'When ignoring columns id and random:     indication diabetes  ihd hypertension arrhythmia history  ipsi contra  \\\n13          CVA       no  yes          yes        yes      no  75.0     50   \n62          A-F       no   no          yes         no      no  75.0    25    \n65          A-F       no  yes          yes         no      no  95.0     40   \n66          A-F       no   no           no         no      no  70.0    20    \n72          TIA       no   no           no         no      no  65.0    30    \n...         ...      ...  ...          ...        ...     ...   ...    ...   \n1515        A-F       no  yes           no         no      no  76.0    60    \n1516        A-F       no   no          yes        yes      no  90.0     75   \n1517        TIA       no   no          yes         no      no  75.0    20    \n1518        A-F       no  yes           no         no      no  70.0    45    \n1519        CVA       no   no           no         no      no  60.0    20    \n\n       label  \n13      Risk  \n62    NoRisk  \n65      Risk  \n66    NoRisk  \n72    NoRisk  \n...      ...  \n1515  NoRisk  \n1516    Risk  \n1517  NoRisk  \n1518  NoRisk  \n1519  NoRisk  \n\n[1094 rows x 9 columns]',
#               'When ignoring columns contra and id:        random indication diabetes ihd hypertension arrhythmia history  ipsi  \\\n1134  0.724246        CVA       no  no          yes         no      no  73.0   \n\n       label  \n1134  NoRisk  ',
#               'When ignoring columns id and random and indication:     diabetes  ihd hypertension arrhythmia history  ipsi contra   label\n13         no  yes          yes        yes      no  75.0     50    Risk\n16         no  yes          yes        yes      no  90.0    100    Risk\n40         no   no           no         no      no  70.0    20   NoRisk\n47         no   no          yes         no      no  70.0    20   NoRisk\n57         no  yes           no         no      no  76.0    50   NoRisk\n...       ...  ...          ...        ...     ...   ...    ...     ...\n1515       no  yes           no         no      no  76.0    60   NoRisk\n1516       no   no          yes        yes      no  90.0     75    Risk\n1517       no   no          yes         no      no  75.0    20   NoRisk\n1518       no  yes           no         no      no  70.0    45   NoRisk\n1519       no   no           no         no      no  60.0    20   NoRisk\n\n[1157 rows x 8 columns]',
#               'When ignoring columns id and random and diabetes:     indication  ihd hypertension arrhythmia history  ipsi contra   label\n13          CVA  yes          yes        yes      no  75.0     50    Risk\n62          A-F   no          yes         no      no  75.0    25   NoRisk\n65          A-F  yes          yes         no      no  95.0     40    Risk\n66          A-F   no           no         no      no  70.0    20   NoRisk\n72          TIA   no           no         no      no  65.0    30   NoRisk\n...         ...  ...          ...        ...     ...   ...    ...     ...\n1515        A-F  yes           no         no      no  76.0    60   NoRisk\n1516        A-F   no          yes        yes      no  90.0     75    Risk\n1517        TIA   no          yes         no      no  75.0    20   NoRisk\n1518        A-F  yes           no         no      no  70.0    45   NoRisk\n1519        CVA   no           no         no      no  60.0    20   NoRisk\n\n[1100 rows x 8 columns]',
#               'When ignoring columns id and random and ihd:     indication diabetes hypertension arrhythmia history  ipsi contra   label\n13          CVA       no          yes        yes      no  75.0     50    Risk\n62          A-F       no          yes         no      no  75.0    25   NoRisk\n65          A-F       no          yes         no      no  95.0     40    Risk\n66          A-F       no           no         no      no  70.0    20   NoRisk\n72          TIA       no           no         no      no  65.0    30   NoRisk\n...         ...      ...          ...        ...     ...   ...    ...     ...\n1515        A-F       no           no         no      no  76.0    60   NoRisk\n1516        A-F       no          yes        yes      no  90.0     75    Risk\n1517        TIA       no          yes         no      no  75.0    20   NoRisk\n1518        A-F       no           no         no      no  70.0    45   NoRisk\n1519        CVA       no           no         no      no  60.0    20   NoRisk\n\n[1112 rows x 8 columns]',
#               'When ignoring columns id and random and hypertension:     indication diabetes  ihd arrhythmia history  ipsi contra   label\n13          CVA       no  yes        yes      no  75.0     50    Risk\n38          CVA       no   no         no      no  70.0    20   NoRisk\n47          A-F       no   no         no      no  70.0    20   NoRisk\n62          A-F       no   no         no      no  75.0    25   NoRisk\n65          A-F       no  yes         no      no  95.0     40    Risk\n...         ...      ...  ...        ...     ...   ...    ...     ...\n1515        A-F       no  yes         no      no  76.0    60   NoRisk\n1516        A-F       no   no        yes      no  90.0     75    Risk\n1517        TIA       no   no         no      no  75.0    20   NoRisk\n1518        A-F       no  yes         no      no  70.0    45   NoRisk\n1519        CVA       no   no         no      no  60.0    20   NoRisk\n\n[1123 rows x 8 columns]',
#               'When ignoring columns id and random and arrhythmia:     indication diabetes  ihd hypertension history  ipsi contra   label\n13          CVA       no  yes          yes      no  75.0     50    Risk\n62          A-F       no   no          yes      no  75.0    25   NoRisk\n65          A-F       no  yes          yes      no  95.0     40    Risk\n66          A-F       no   no           no      no  70.0    20   NoRisk\n72          TIA       no   no           no      no  65.0    30   NoRisk\n...         ...      ...  ...          ...     ...   ...    ...     ...\n1515        A-F       no  yes           no      no  76.0    60   NoRisk\n1516        A-F       no   no          yes      no  90.0     75    Risk\n1517        TIA       no   no          yes      no  75.0    20   NoRisk\n1518        A-F       no  yes           no      no  70.0    45   NoRisk\n1519        CVA       no   no           no      no  60.0    20   NoRisk\n\n[1111 rows x 8 columns]',
#               'When ignoring columns id and random and history:     indication diabetes  ihd hypertension arrhythmia  ipsi contra   label\n13          CVA       no  yes          yes        yes  75.0     50    Risk\n62          A-F       no   no          yes         no  75.0    25   NoRisk\n65          A-F       no  yes          yes         no  95.0     40    Risk\n66          A-F       no   no           no         no  70.0    20   NoRisk\n72          TIA       no   no           no         no  65.0    30   NoRisk\n...         ...      ...  ...          ...        ...   ...    ...     ...\n1515        A-F       no  yes           no         no  76.0    60   NoRisk\n1516        A-F       no   no          yes        yes  90.0     75    Risk\n1517        TIA       no   no          yes         no  75.0    20   NoRisk\n1518        A-F       no  yes           no         no  70.0    45   NoRisk\n1519        CVA       no   no           no         no  60.0    20   NoRisk\n\n[1097 rows x 8 columns]',
#               'When ignoring columns id and random and ipsi:     indication diabetes  ihd hypertension arrhythmia history contra   label\n11          A-F       no  yes          yes         no      no     40    Risk\n13          CVA       no  yes          yes        yes      no     50    Risk\n23          CVA       no   no           no         no      no    60   NoRisk\n26          CVA       no   no          yes         no      no    40   NoRisk\n30          CVA       no   no           no         no      no    60   NoRisk\n...         ...      ...  ...          ...        ...     ...    ...     ...\n1515        A-F       no  yes           no         no      no    60   NoRisk\n1516        A-F       no   no          yes        yes      no     75    Risk\n1517        TIA       no   no          yes         no      no    20   NoRisk\n1518        A-F       no  yes           no         no      no    45   NoRisk\n1519        CVA       no   no           no         no      no    20   NoRisk\n\n[1252 rows x 8 columns]',
#               'When ignoring columns id and random and contra:     indication diabetes  ihd hypertension arrhythmia history  ipsi   label\n13          CVA       no  yes          yes        yes      no  75.0    Risk\n24          TIA       no   no          yes         no      no  81.0  NoRisk\n25          A-F       no  yes           no         no      no  76.0  NoRisk\n27          A-F       no   no          yes         no      no  75.0  NoRisk\n32          A-F       no  yes          yes         no      no  90.0    Risk\n...         ...      ...  ...          ...        ...     ...   ...     ...\n1515        A-F       no  yes           no         no      no  76.0  NoRisk\n1516        A-F       no   no          yes        yes      no  90.0    Risk\n1517        TIA       no   no          yes         no      no  75.0  NoRisk\n1518        A-F       no  yes           no         no      no  70.0  NoRisk\n1519        CVA       no   no           no         no      no  60.0  NoRisk\n\n[1247 rows x 8 columns]',
#               'When ignoring columns id and random and label:     indication diabetes  ihd hypertension arrhythmia history  ipsi contra\n13          CVA       no  yes          yes        yes      no  75.0     50\n62          A-F       no   no          yes         no      no  75.0    25 \n65          A-F       no  yes          yes         no      no  95.0     40\n66          A-F       no   no           no         no      no  70.0    20 \n72          TIA       no   no           no         no      no  65.0    30 \n...         ...      ...  ...          ...        ...     ...   ...    ...\n1515        A-F       no  yes           no         no      no  76.0    60 \n1516        A-F       no   no          yes        yes      no  90.0     75\n1517        TIA       no   no          yes         no      no  75.0    20 \n1518        A-F       no  yes           no         no      no  70.0    45 \n1519        CVA       no   no           no         no      no  60.0    20 \n\n[1095 rows x 8 columns]',
#               ('When ignoring columns id and random:',
#                     indication diabetes  ihd hypertension arrhythmia history  ipsi contra  \
#                13          CVA       no  yes          yes        yes      no  75.0     50
#                62          A-F       no   no          yes         no      no  75.0    25
#                65          A-F       no  yes          yes         no      no  95.0     40
#                66          A-F       no   no           no         no      no  70.0    20
#                72          TIA       no   no           no         no      no  65.0    30
#                ...         ...      ...  ...          ...        ...     ...   ...    ...
#                1515        A-F       no  yes           no         no      no  76.0    60
#                1516        A-F       no   no          yes        yes      no  90.0     75
#                1517        TIA       no   no          yes         no      no  75.0    20
#                1518        A-F       no  yes           no         no      no  70.0    45
#                1519        CVA       no   no           no         no      no  60.0    20
#
#                       label
#                13      Risk
#                62    NoRisk
#                65      Risk
#                66    NoRisk
#                72    NoRisk
#                ...      ...
#                1515  NoRisk
#                1516    Risk
#                1517  NoRisk
#                1518  NoRisk
#                1519  NoRisk
#
#                [1094 rows x 9 columns]),
#               ('When ignoring columns contra and id:',
#                        random indication diabetes ihd hypertension arrhythmia history  ipsi  \
#                1134  0.724246        CVA       no  no          yes         no      no  73.0
#
#                       label
#                1134  NoRisk  ),
#               ('When ignoring columns id and random and indication:',
#                     diabetes  ihd hypertension arrhythmia history  ipsi contra   label
#                13         no  yes          yes        yes      no  75.0     50    Risk
#                16         no  yes          yes        yes      no  90.0    100    Risk
#                40         no   no           no         no      no  70.0    20   NoRisk
#                47         no   no          yes         no      no  70.0    20   NoRisk
#                57         no  yes           no         no      no  76.0    50   NoRisk
#                ...       ...  ...          ...        ...     ...   ...    ...     ...
#                1515       no  yes           no         no      no  76.0    60   NoRisk
#                1516       no   no          yes        yes      no  90.0     75    Risk
#                1517       no   no          yes         no      no  75.0    20   NoRisk
#                1518       no  yes           no         no      no  70.0    45   NoRisk
#                1519       no   no           no         no      no  60.0    20   NoRisk
#
#                [1157 rows x 8 columns]),
#               ('When ignoring columns id and random and diabetes:',
#                     indication  ihd hypertension arrhythmia history  ipsi contra   label
#                13          CVA  yes          yes        yes      no  75.0     50    Risk
#                62          A-F   no          yes         no      no  75.0    25   NoRisk
#                65          A-F  yes          yes         no      no  95.0     40    Risk
#                66          A-F   no           no         no      no  70.0    20   NoRisk
#                72          TIA   no           no         no      no  65.0    30   NoRisk
#                ...         ...  ...          ...        ...     ...   ...    ...     ...
#                1515        A-F  yes           no         no      no  76.0    60   NoRisk
#                1516        A-F   no          yes        yes      no  90.0     75    Risk
#                1517        TIA   no          yes         no      no  75.0    20   NoRisk
#                1518        A-F  yes           no         no      no  70.0    45   NoRisk
#                1519        CVA   no           no         no      no  60.0    20   NoRisk
#
#                [1100 rows x 8 columns]),
#               ('When ignoring columns id and random and ihd:',
#                     indication diabetes hypertension arrhythmia history  ipsi contra   label
#                13          CVA       no          yes        yes      no  75.0     50    Risk
#                62          A-F       no          yes         no      no  75.0    25   NoRisk
#                65          A-F       no          yes         no      no  95.0     40    Risk
#                66          A-F       no           no         no      no  70.0    20   NoRisk
#                72          TIA       no           no         no      no  65.0    30   NoRisk
#                ...         ...      ...          ...        ...     ...   ...    ...     ...
#                1515        A-F       no           no         no      no  76.0    60   NoRisk
#                1516        A-F       no          yes        yes      no  90.0     75    Risk
#                1517        TIA       no          yes         no      no  75.0    20   NoRisk
#                1518        A-F       no           no         no      no  70.0    45   NoRisk
#                1519        CVA       no           no         no      no  60.0    20   NoRisk
#
#                [1112 rows x 8 columns]),
#               ('When ignoring columns id and random and hypertension:',
#                     indication diabetes  ihd arrhythmia history  ipsi contra   label
#                13          CVA       no  yes        yes      no  75.0     50    Risk
#                38          CVA       no   no         no      no  70.0    20   NoRisk
#                47          A-F       no   no         no      no  70.0    20   NoRisk
#                62          A-F       no   no         no      no  75.0    25   NoRisk
#                65          A-F       no  yes         no      no  95.0     40    Risk
#                ...         ...      ...  ...        ...     ...   ...    ...     ...
#                1515        A-F       no  yes         no      no  76.0    60   NoRisk
#                1516        A-F       no   no        yes      no  90.0     75    Risk
#                1517        TIA       no   no         no      no  75.0    20   NoRisk
#                1518        A-F       no  yes         no      no  70.0    45   NoRisk
#                1519        CVA       no   no         no      no  60.0    20   NoRisk
#
#                [1123 rows x 8 columns]),
#               ('When ignoring columns id and random and arrhythmia:',
#                     indication diabetes  ihd hypertension history  ipsi contra   label
#                13          CVA       no  yes          yes      no  75.0     50    Risk
#                62          A-F       no   no          yes      no  75.0    25   NoRisk
#                65          A-F       no  yes          yes      no  95.0     40    Risk
#                66          A-F       no   no           no      no  70.0    20   NoRisk
#                72          TIA       no   no           no      no  65.0    30   NoRisk
#                ...         ...      ...  ...          ...     ...   ...    ...     ...
#                1515        A-F       no  yes           no      no  76.0    60   NoRisk
#                1516        A-F       no   no          yes      no  90.0     75    Risk
#                1517        TIA       no   no          yes      no  75.0    20   NoRisk
#                1518        A-F       no  yes           no      no  70.0    45   NoRisk
#                1519        CVA       no   no           no      no  60.0    20   NoRisk
#
#                [1111 rows x 8 columns]),
#               ('When ignoring columns id and random and history:',
#                     indication diabetes  ihd hypertension arrhythmia  ipsi contra   label
#                13          CVA       no  yes          yes        yes  75.0     50    Risk
#                62          A-F       no   no          yes         no  75.0    25   NoRisk
#                65          A-F       no  yes          yes         no  95.0     40    Risk
#                66          A-F       no   no           no         no  70.0    20   NoRisk
#                72          TIA       no   no           no         no  65.0    30   NoRisk
#                ...         ...      ...  ...          ...        ...   ...    ...     ...
#                1515        A-F       no  yes           no         no  76.0    60   NoRisk
#                1516        A-F       no   no          yes        yes  90.0     75    Risk
#                1517        TIA       no   no          yes         no  75.0    20   NoRisk
#                1518        A-F       no  yes           no         no  70.0    45   NoRisk
#                1519        CVA       no   no           no         no  60.0    20   NoRisk
#
#                [1097 rows x 8 columns]),
#               ('When ignoring columns id and random and ipsi:',
#                     indication diabetes  ihd hypertension arrhythmia history contra   label
#                11          A-F       no  yes          yes         no      no     40    Risk
#                13          CVA       no  yes          yes        yes      no     50    Risk
#                23          CVA       no   no           no         no      no    60   NoRisk
#                26          CVA       no   no          yes         no      no    40   NoRisk
#                30          CVA       no   no           no         no      no    60   NoRisk
#                ...         ...      ...  ...          ...        ...     ...    ...     ...
#                1515        A-F       no  yes           no         no      no    60   NoRisk
#                1516        A-F       no   no          yes        yes      no     75    Risk
#                1517        TIA       no   no          yes         no      no    20   NoRisk
#                1518        A-F       no  yes           no         no      no    45   NoRisk
#                1519        CVA       no   no           no         no      no    20   NoRisk
#
#                [1252 rows x 8 columns]),
#               ('When ignoring columns id and random and contra:',
#                     indication diabetes  ihd hypertension arrhythmia history  ipsi   label
#                13          CVA       no  yes          yes        yes      no  75.0    Risk
#                24          TIA       no   no          yes         no      no  81.0  NoRisk
#                25          A-F       no  yes           no         no      no  76.0  NoRisk
#                27          A-F       no   no          yes         no      no  75.0  NoRisk
#                32          A-F       no  yes          yes         no      no  90.0    Risk
#                ...         ...      ...  ...          ...        ...     ...   ...     ...
#                1515        A-F       no  yes           no         no      no  76.0  NoRisk
#                1516        A-F       no   no          yes        yes      no  90.0    Risk
#                1517        TIA       no   no          yes         no      no  75.0  NoRisk
#                1518        A-F       no  yes           no         no      no  70.0  NoRisk
#                1519        CVA       no   no           no         no      no  60.0  NoRisk
#
#                [1247 rows x 8 columns]),
#               ('When ignoring columns id and random and label:',
#                     indication diabetes  ihd hypertension arrhythmia history  ipsi contra
#                13          CVA       no  yes          yes        yes      no  75.0     50
#                62          A-F       no   no          yes         no      no  75.0    25
#                65          A-F       no  yes          yes         no      no  95.0     40
#                66          A-F       no   no           no         no      no  70.0    20
#                72          TIA       no   no           no         no      no  65.0    30
#                ...         ...      ...  ...          ...        ...     ...   ...    ...
#                1515        A-F       no  yes           no         no      no  76.0    60
#                1516        A-F       no   no          yes        yes      no  90.0     75
#                1517        TIA       no   no          yes         no      no  75.0    20
#                1518        A-F       no  yes           no         no      no  70.0    45
#                1519        CVA       no   no           no         no      no  60.0    20
#
#                [1095 rows x 8 columns]),
#               'When ignoring columns id and random and indication:     diabetes  ihd hypertension arrhythmia history  ipsi contra   label\n13         no  yes          yes        yes      no  75.0     50    Risk\n16         no  yes          yes        yes      no  90.0    100    Risk\n40         no   no           no         no      no  70.0    20   NoRisk\n47         no   no          yes         no      no  70.0    20   NoRisk\n57         no  yes           no         no      no  76.0    50   NoRisk\n...       ...  ...          ...        ...     ...   ...    ...     ...\n1515       no  yes           no         no      no  76.0    60   NoRisk\n1516       no   no          yes        yes      no  90.0     75    Risk\n1517       no   no          yes         no      no  75.0    20   NoRisk\n1518       no  yes           no         no      no  70.0    45   NoRisk\n1519       no   no           no         no      no  60.0    20   NoRisk\n\n[1157 rows x 8 columns]',
#               'When ignoring columns id and random and diabetes:     indication  ihd hypertension arrhythmia history  ipsi contra   label\n13          CVA  yes          yes        yes      no  75.0     50    Risk\n62          A-F   no          yes         no      no  75.0    25   NoRisk\n65          A-F  yes          yes         no      no  95.0     40    Risk\n66          A-F   no           no         no      no  70.0    20   NoRisk\n72          TIA   no           no         no      no  65.0    30   NoRisk\n...         ...  ...          ...        ...     ...   ...    ...     ...\n1515        A-F  yes           no         no      no  76.0    60   NoRisk\n1516        A-F   no          yes        yes      no  90.0     75    Risk\n1517        TIA   no          yes         no      no  75.0    20   NoRisk\n1518        A-F  yes           no         no      no  70.0    45   NoRisk\n1519        CVA   no           no         no      no  60.0    20   NoRisk\n\n[1100 rows x 8 columns]',
#               'When ignoring columns id and random and ihd:     indication diabetes hypertension arrhythmia history  ipsi contra   label\n13          CVA       no          yes        yes      no  75.0     50    Risk\n62          A-F       no          yes         no      no  75.0    25   NoRisk\n65          A-F       no          yes         no      no  95.0     40    Risk\n66          A-F       no           no         no      no  70.0    20   NoRisk\n72          TIA       no           no         no      no  65.0    30   NoRisk\n...         ...      ...          ...        ...     ...   ...    ...     ...\n1515        A-F       no           no         no      no  76.0    60   NoRisk\n1516        A-F       no          yes        yes      no  90.0     75    Risk\n1517        TIA       no          yes         no      no  75.0    20   NoRisk\n1518        A-F       no           no         no      no  70.0    45   NoRisk\n1519        CVA       no           no         no      no  60.0    20   NoRisk\n\n[1112 rows x 8 columns]',
#               'When ignoring columns id and random and hypertension:     indication diabetes  ihd arrhythmia history  ipsi contra   label\n13          CVA       no  yes        yes      no  75.0     50    Risk\n38          CVA       no   no         no      no  70.0    20   NoRisk\n47          A-F       no   no         no      no  70.0    20   NoRisk\n62          A-F       no   no         no      no  75.0    25   NoRisk\n65          A-F       no  yes         no      no  95.0     40    Risk\n...         ...      ...  ...        ...     ...   ...    ...     ...\n1515        A-F       no  yes         no      no  76.0    60   NoRisk\n1516        A-F       no   no        yes      no  90.0     75    Risk\n1517        TIA       no   no         no      no  75.0    20   NoRisk\n1518        A-F       no  yes         no      no  70.0    45   NoRisk\n1519        CVA       no   no         no      no  60.0    20   NoRisk\n\n[1123 rows x 8 columns]',
#               'When ignoring columns id and random and arrhythmia:     indication diabetes  ihd hypertension history  ipsi contra   label\n13          CVA       no  yes          yes      no  75.0     50    Risk\n62          A-F       no   no          yes      no  75.0    25   NoRisk\n65          A-F       no  yes          yes      no  95.0     40    Risk\n66          A-F       no   no           no      no  70.0    20   NoRisk\n72          TIA       no   no           no      no  65.0    30   NoRisk\n...         ...      ...  ...          ...     ...   ...    ...     ...\n1515        A-F       no  yes           no      no  76.0    60   NoRisk\n1516        A-F       no   no          yes      no  90.0     75    Risk\n1517        TIA       no   no          yes      no  75.0    20   NoRisk\n1518        A-F       no  yes           no      no  70.0    45   NoRisk\n1519        CVA       no   no           no      no  60.0    20   NoRisk\n\n[1111 rows x 8 columns]',
#               'When ignoring columns id and random and history:     indication diabetes  ihd hypertension arrhythmia  ipsi contra   label\n13          CVA       no  yes          yes        yes  75.0     50    Risk\n62          A-F       no   no          yes         no  75.0    25   NoRisk\n65          A-F       no  yes          yes         no  95.0     40    Risk\n66          A-F       no   no           no         no  70.0    20   NoRisk\n72          TIA       no   no           no         no  65.0    30   NoRisk\n...         ...      ...  ...          ...        ...   ...    ...     ...\n1515        A-F       no  yes           no         no  76.0    60   NoRisk\n1516        A-F       no   no          yes        yes  90.0     75    Risk\n1517        TIA       no   no          yes         no  75.0    20   NoRisk\n1518        A-F       no  yes           no         no  70.0    45   NoRisk\n1519        CVA       no   no           no         no  60.0    20   NoRisk\n\n[1097 rows x 8 columns]',
#               'When ignoring columns id and random and ipsi:     indication diabetes  ihd hypertension arrhythmia history contra   label\n11          A-F       no  yes          yes         no      no     40    Risk\n13          CVA       no  yes          yes        yes      no     50    Risk\n23          CVA       no   no           no         no      no    60   NoRisk\n26          CVA       no   no          yes         no      no    40   NoRisk\n30          CVA       no   no           no         no      no    60   NoRisk\n...         ...      ...  ...          ...        ...     ...    ...     ...\n1515        A-F       no  yes           no         no      no    60   NoRisk\n1516        A-F       no   no          yes        yes      no     75    Risk\n1517        TIA       no   no          yes         no      no    20   NoRisk\n1518        A-F       no  yes           no         no      no    45   NoRisk\n1519        CVA       no   no           no         no      no    20   NoRisk\n\n[1252 rows x 8 columns]',
#               'When ignoring columns id and random and contra:     indication diabetes  ihd hypertension arrhythmia history  ipsi   label\n13          CVA       no  yes          yes        yes      no  75.0    Risk\n24          TIA       no   no          yes         no      no  81.0  NoRisk\n25          A-F       no  yes           no         no      no  76.0  NoRisk\n27          A-F       no   no          yes         no      no  75.0  NoRisk\n32          A-F       no  yes          yes         no      no  90.0    Risk\n...         ...      ...  ...          ...        ...     ...   ...     ...\n1515        A-F       no  yes           no         no      no  76.0  NoRisk\n1516        A-F       no   no          yes        yes      no  90.0    Risk\n1517        TIA       no   no          yes         no      no  75.0  NoRisk\n1518        A-F       no  yes           no         no      no  70.0  NoRisk\n1519        CVA       no   no           no         no      no  60.0  NoRisk\n\n[1247 rows x 8 columns]',
#               'When ignoring columns id and random and label:     indication diabetes  ihd hypertension arrhythmia history  ipsi contra\n13          CVA       no  yes          yes        yes      no  75.0     50\n62          A-F       no   no          yes         no      no  75.0    25 \n65          A-F       no  yes          yes         no      no  95.0     40\n66          A-F       no   no           no         no      no  70.0    20 \n72          TIA       no   no           no         no      no  65.0    30 \n...         ...      ...  ...          ...        ...     ...   ...    ...\n1515        A-F       no  yes           no         no      no  76.0    60 \n1516        A-F       no   no          yes        yes      no  90.0     75\n1517        TIA       no   no          yes         no      no  75.0    20 \n1518        A-F       no  yes           no         no      no  70.0    45 \n1519        CVA       no   no           no         no      no  60.0    20 \n\n[1095 rows x 8 columns]']})

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="126"></a>
# <h4>1.2.6. Actions</h4>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="13"></a>
# <h3>1.3. Data Preparation</h3>

# %% [markdown]
# <a id="131"></a>
# <h4>1.3.1. Cleaning</h4>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="132"></a>
# <h4>1.3.2. Transformation</h4>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="133"></a>
# <h4>1.3.3. Stratification (TTS)</h4>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="14"></a>
# <h3>1.4. Modeling</h3>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="15"></a>
# <h3>1.5. Evaluation</h3>

# %% [markdown]
# <a href="#0">[back to top]</a>

# %% [markdown]
# <a id="16"></a>
# <h3>1.6. (Theoretical) Deployment</h3>

# %% [markdown]
# <a href="#0">[back to top]</a>
