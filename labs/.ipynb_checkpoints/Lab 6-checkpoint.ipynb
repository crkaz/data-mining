# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn as skl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from sklearn.datasets import load_iris
from sklearn import metrics, model_selection, linear_model
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse

# %%
data = load_iris()

# %%
dfRaw = pd.DataFrame(data= np.c_[data['data'], data['target']],
                     columns= data['feature_names'] + ['target'])

dfRaw
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %%
df = dfRaw # Create working copy.
x = df.drop(['target'], axis=1)
y = df["target"]

# %%
def GetClassName(data, n):
    n = int(n)
    return data.target_names[n]

def PlotXY(x, y):
    plt.figure(figsize=(20,10))
    nCols = len(x.columns.values)
    i =0
    for col in x.columns.values:
        plt.subplot(2, nCols, i + 1 )
        plt.xlabel(col)
        plt.ylabel("Class")
        plt.scatter(x[col], y, marker="x")
        i += 1

# %%
PlotXY(x,y)

# %%
xtr, xte, ytr, yte = skl.model_selection.train_test_split(x, y, test_size=0.3, shuffle=True)

# %%
PlotXY(xtr, ytr)

# %%
PlotXY(xte, yte)
