# %% [markdown]
# # Data Mining and Decision Systems ACW
# ## October 2019
# #### Student number: 201601628
# #### Zak Catherall
# <hr>

# %% [markdown]
# ## Initial Work

# %% [markdown]
# #### Imports

# %%
# %config IPCompleter.greedy=True
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### Global Vars

# %%
PATH = "data.csv"

# %% [markdown]
# #### Load Data

# %%
dfRaw = pd.read_csv(PATH)
dfRaw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 11 columns):
# Random          1520 non-null float64
# Id              1520 non-null int64
# Indication      1517 non-null object
# Diabetes        1518 non-null object
# IHD             1520 non-null object
# Hypertension    1517 non-null object
# Arrhythmia      1520 non-null object
# History         1518 non-null object
# IPSI            1516 non-null float64
# Contra          1520 non-null object
# label           1517 non-null object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 130.8+ KB

# %% [markdown]
# <b>Looking at the data dictionary it can be seen that the, "Random" attribute is unique and it's purpose is only for sorting, so it can be discarded to reduce the search space.</b>
#
# However, first it should be checked that the data conforms to this assumption.

# %%
print(dfRaw["Random"].unique().shape[0])
print(dfRaw.shape[0])
diff = dfRaw["Random"].unique().shape[0]-dfRaw.shape[0]
print("Difference = " + str(abs(diff)))
# Out:
# 1222
# 1520
# Difference = 298

# %% [markdown]
# Based off the previous line of code, something is awry. Immediate assumptions are that some records are missing the data.

# %%
dfRaw[dfRaw["Random"].duplicated()]
# Out:
#         Random      Id Indication Diabetes  IHD Hypertension Arrhythmia  \
# 1     0.602437  159284        TIA       no   no           no         no
# 2     0.602437  106066        A-F       no  yes          yes         no
# 10    0.678157  174588        CVA       no  yes          yes        yes
# 15    0.025356  219417        CVA       no  yes          yes        yes
# 19    0.065821  101248        ASx      yes   no          yes         no
# ...        ...     ...        ...      ...  ...          ...        ...
# 1457  0.754513  293073        A-F       no  yes           no        yes
# 1459  0.735681  151183        CVA       no   no           no         no
# 1467  0.889219  202550        TIA       no   no          yes         no
# 1511  0.174637  284804        TIA       no  yes           no         no
# 1515  0.391440   93406        A-F       no  yes           no         no
#
#      History  IPSI Contra   label
# 1         no  70.0    60   NoRisk
# 2         no  95.0     40    Risk
# 10        no  75.0     50    Risk
# 15        no  90.0    100    Risk
# 19        no  80.0     80    Risk
# ...      ...   ...    ...     ...
# 1457      no  95.0    100    Risk
# 1459      no  75.0    90   NoRisk
# 1467      no  77.0    20   NoRisk
# 1511      no  73.0    30   NoRisk
# 1515      no  76.0    60   NoRisk
#
# [298 rows x 11 columns]

# %% [markdown]
# The assumption was incorrect, and actually there are 298 duplicate records, which is equal to the difference between the number of unique values and expected.
#
# <b>However, in this instance, the purpose of the feature is still unrelated to the label, so we'll remove it anyway.</b>

# %%
df = dfRaw.drop(["Random"], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 10 columns):
# Id              1520 non-null int64
# Indication      1517 non-null object
# Diabetes        1518 non-null object
# IHD             1520 non-null object
# Hypertension    1517 non-null object
# Arrhythmia      1520 non-null object
# History         1518 non-null object
# IPSI            1516 non-null float64
# Contra          1520 non-null object
# label           1517 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 118.9+ KB

# %% [markdown]
# The next way we can reduce the search space is by reducing any binary features to 1 column and encoding as 1 or 0.
#
# Again, we'll first check if each of the columns violate the data dictionary first.

# %%
binaryCols = ["Diabetes","IHD","Hypertension","Arrhythmia","History","label"]

for col in binaryCols:
    uniqueValues = df[col].unique()
    nUnique = uniqueValues.shape[0]
    if nUnique != 2:
        print(col + " column has " + str(nUnique) + " values - see below:")
        print(uniqueValues)
# Out:
# Diabetes column has 3 values - see below:
# ['no' 'yes' nan]
# Hypertension column has 3 values - see below:
# ['yes' 'no' nan]
# History column has 3 values - see below:
# ['no' 'yes' nan]
# label column has 4 values - see below:
# ['NoRisk' 'Risk' 'Unknown' nan]

# %% [markdown]
# Having identified these inconsistencies, they should be measured to calculate the best approach between removing records with unexpected values and estimating them.
#
# Of particular interest in the label column, since it provides our classification. Also note the lower case 'l' described as upper case in the dictionary.

# %%
colsWithNan = ["Diabetes","Hypertension","History"] # Excluding label as a special case.

for col in colsWithNan:
#     nNan = df[df[col] == np.nan]
#     print(col + " column has " + str(nNan) + " nan entries.")
#     print(df[df[col] == np.nan].shape)
    nYes = df[df[col] == "yes"].shape[0]
    nNo = df[df[col] == "no"].shape[0]        
    ynSum = nYes + nNo
    nNan = df[col].shape[0] - ynSum
    print(col + " column has " +str(nNan) + " nan entries.")
# Out:
# Diabetes column has 2 nan entries.
# Hypertension column has 3 nan entries.
# History column has 2 nan entries.

# %% [markdown]
# So absolute worse case, if nothing can be done about the data (and for the quantity it probably isn't worth it anyway), 7 records would be removed (before looking at the complications with the label column.
#
# <b>For now I'll remove them and look into label.</b>

# %%
nRBefore = df.shape[0]
print(str(nRBefore) + " records before removing nan records.")
df.dropna(subset=colsWithNan, inplace=True)
nRAfter = df.shape[0]
print(str(nRAfter) + " records after removing nan records.")
nRemoved = nRBefore - nRAfter
print(str(nRemoved) + " records removed.")
# Out:
# 1520 records before removing nan records.
# 1513 records after removing nan records.
# 7 records removed.

# %% [markdown]
# Repeat for label column.

# %%
nYes = df[df["label"] == "Risk"].shape[0]
nNo = df[df["label"] == "NoRisk"].shape[0]        
nUnknown = df[df["label"] == "Unknown"].shape[0]
print("label column has " +str(nUnknown) + " unknown entries.")
ynSum = nYes + nNo + nUnknown
nNan = df["label"].shape[0] - ynSum
print("label column has " +str(nNan) + " nan entries.")
# Out:
# label column has 2 unknown entries.
# label column has 3 nan entries.

# %%
nRBefore = df.shape[0]
print(str(nRBefore) + " records before removing nan records.")
df.dropna(subset=["label"], inplace=True)
nRAfter = df.shape[0]
print(str(nRAfter) + " records after removing nan records.")
nRemoved = nRBefore - nRAfter
print(str(nRemoved) + " records removed.")
# Out:
# 1513 records before removing nan records.
# 1510 records after removing nan records.
# 3 records removed.

# %% [markdown]
# Total of 10/1520 records lost to nan - acceptable. That just leaves the "Unknowns" of which there are 2 - they can be put to the side/dropped for now. It may be possible to estimate the values and/or calculate with the classifier model later as a test.

# %%
nRBefore = df.shape[0]
print(str(nRBefore) + " records before removing nan records.")

unknowns = df[df["label"] == "Unknown"]
for i in unknowns.index:
    print("Removing record at index " +  str(i))
    df.drop(index=i, inplace=True)
    
nRAfter = df.shape[0]
print(str(nRAfter) + " records after removing nan records.")
nRemoved = nRBefore - nRAfter
print(str(nRemoved) + " records removed.")
# Out:
# 1510 records before removing nan records.
# Removing record at index 475
# Removing record at index 523
# 1508 records after removing nan records.
# 2 records removed.

# %% [markdown]
# <b>We can now re-run the recent code to confirm the edits we made have had the expected effect.</b>
#
# <b>We've lost a total of 12 records out of the original 1520 (0.79%) leaving us with <u>1508</u>.</b>

# %% [markdown]
# Let's look at the ID field which should be mostly unique aside from multiple visits.

# %%
nDupeIDs = df[df["Id"].duplicated() == True].shape[0]

print("There are " + str(nDupeIDs) + " duplicate IDs.")
# Out:
# There are 0 duplicate IDs.

# %% [markdown]
# For current analysis (our snapshot) we don't need to be too concerned with the face that multiple ids/patient visits can occur.

# %%
df.describe(include='all')
# Out:
#                    Id Indication Diabetes   IHD Hypertension Arrhythmia  \
# count     1508.000000       1505     1508  1508         1508       1508
# unique            NaN          5        2     2            2          2
# top               NaN        A-F       no    no           no         no
# freq              NaN        491     1433   794          782       1183
# mean    188164.220822        NaN      NaN   NaN          NaN        NaN
# std      64451.543917        NaN      NaN   NaN          NaN        NaN
# min      78261.000000        NaN      NaN   NaN          NaN        NaN
# 25%     136173.750000        NaN      NaN   NaN          NaN        NaN
# 50%     191284.500000        NaN      NaN   NaN          NaN        NaN
# 75%     244559.500000        NaN      NaN   NaN          NaN        NaN
# max     295978.000000        NaN      NaN   NaN          NaN        NaN
#
#        History         IPSI Contra   label
# count     1508  1504.000000   1508    1508
# unique       2          NaN     41       2
# top         no          NaN    100  NoRisk
# freq      1485          NaN    241    1004
# mean       NaN    78.830452    NaN     NaN
# std        NaN    10.164507    NaN     NaN
# min        NaN    35.000000    NaN     NaN
# 25%        NaN    73.000000    NaN     NaN
# 50%        NaN    77.000000    NaN     NaN
# 75%        NaN    85.000000    NaN     NaN
# max        NaN    99.000000    NaN     NaN

# %%
ynCols = ["Diabetes","IHD","Hypertension","Arrhythmia","History"]

df = pd.concat([df, pd.get_dummies(df[ynCols])], axis=1)
df = df.drop(columns=ynCols)
df
# Out:
#           Id Indication  IPSI Contra   label  Diabetes_no  Diabetes_yes  \
# 0     218242        A-F  78.0    20   NoRisk            1             0
# 1     159284        TIA  70.0    60   NoRisk            1             0
# 2     106066        A-F  95.0     40    Risk            1             0
# 3     229592        TIA  90.0     85    Risk            1             0
# 4     245829        CVA  70.0    20   NoRisk            1             0
# ...      ...        ...   ...    ...     ...          ...           ...
# 1515   93406        A-F  76.0    60   NoRisk            1             0
# 1516  121814        A-F  90.0     75    Risk            1             0
# 1517  101754        TIA  75.0    20   NoRisk            1             0
# 1518  263836        A-F  70.0    45   NoRisk            1             0
# 1519  254941        CVA  60.0    20   NoRisk            1             0
#
#       IHD_no  IHD_yes  Hypertension_no  Hypertension_yes  Arrhythmia_no  \
# 0          1        0                0                 1              1
# 1          1        0                1                 0              1
# 2          0        1                0                 1              1
# 3          1        0                0                 1              1
# 4          1        0                1                 0              1
# ...      ...      ...              ...               ...            ...
# 1515       0        1                1                 0              1
# 1516       1        0                0                 1              0
# 1517       1        0                0                 1              1
# 1518       0        1                1                 0              1
# 1519       1        0                1                 0              1
#
#       Arrhythmia_yes  History_no  History_yes
# 0                  0           1            0
# 1                  0           1            0
# 2                  0           1            0
# 3                  0           1            0
# 4                  0           1            0
# ...              ...         ...          ...
# 1515               0           1            0
# 1516               1           1            0
# 1517               0           1            0
# 1518               0           1            0
# 1519               0           1            0
#
# [1508 rows x 15 columns]

# %% [markdown]
# We can further simplify the problem space by reducing dimensionality of binary features.

# %%
nCols = ["Diabetes_no","IHD_no","Hypertension_no","Arrhythmia_no","History_no"]
df = df.drop(columns=nCols)
df
# Out:
#           Id Indication  IPSI Contra   label  Diabetes_yes  IHD_yes  \
# 0     218242        A-F  78.0    20   NoRisk             0        0
# 1     159284        TIA  70.0    60   NoRisk             0        0
# 2     106066        A-F  95.0     40    Risk             0        1
# 3     229592        TIA  90.0     85    Risk             0        0
# 4     245829        CVA  70.0    20   NoRisk             0        0
# ...      ...        ...   ...    ...     ...           ...      ...
# 1515   93406        A-F  76.0    60   NoRisk             0        1
# 1516  121814        A-F  90.0     75    Risk             0        0
# 1517  101754        TIA  75.0    20   NoRisk             0        0
# 1518  263836        A-F  70.0    45   NoRisk             0        1
# 1519  254941        CVA  60.0    20   NoRisk             0        0
#
#       Hypertension_yes  Arrhythmia_yes  History_yes
# 0                    1               0            0
# 1                    0               0            0
# 2                    1               0            0
# 3                    1               0            0
# 4                    0               0            0
# ...                ...             ...          ...
# 1515                 0               0            0
# 1516                 1               1            0
# 1517                 1               0            0
# 1518                 0               0            0
# 1519                 0               0            0
#
# [1508 rows x 10 columns]

# %%
df.describe(include="all")
# Out:
#                    Id Indication         IPSI Contra   label  Diabetes_yes  \
# count     1508.000000       1505  1504.000000   1508    1508   1508.000000
# unique            NaN          5          NaN     41       2           NaN
# top               NaN        A-F          NaN    100  NoRisk           NaN
# freq              NaN        491          NaN    241    1004           NaN
# mean    188164.220822        NaN    78.830452    NaN     NaN      0.049735
# std      64451.543917        NaN    10.164507    NaN     NaN      0.217469
# min      78261.000000        NaN    35.000000    NaN     NaN      0.000000
# 25%     136173.750000        NaN    73.000000    NaN     NaN      0.000000
# 50%     191284.500000        NaN    77.000000    NaN     NaN      0.000000
# 75%     244559.500000        NaN    85.000000    NaN     NaN      0.000000
# max     295978.000000        NaN    99.000000    NaN     NaN      1.000000
#
#             IHD_yes  Hypertension_yes  Arrhythmia_yes  History_yes
# count   1508.000000       1508.000000     1508.000000  1508.000000
# unique          NaN               NaN             NaN          NaN
# top             NaN               NaN             NaN          NaN
# freq            NaN               NaN             NaN          NaN
# mean       0.473475          0.481432        0.215517     0.015252
# std        0.499462          0.499821        0.411317     0.122594
# min        0.000000          0.000000        0.000000     0.000000
# 25%        0.000000          0.000000        0.000000     0.000000
# 50%        0.000000          0.000000        0.000000     0.000000
# 75%        1.000000          1.000000        0.000000     0.000000
# max        1.000000          1.000000        1.000000     1.000000

# %%
# label = df["label"]
# for col in df.columns.values:
#     if col == "label":
#         continue
#     else:
#         try:
#             print("Plot for " + col + " and label...")
#             sns.lmplot(x=col, y="label", data=df)            
#         except:
#             print("Failed : non-numeric")

sns.lmplot(x="Diabetes", y="label", data=df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1321ddb34d3c> in <module>
#      10 #             print("Failed : non-numeric")
#      11
# ---> 12 sns.lmplot(x="Diabetes", y="label", data=df)
#
# c:\users\zak\desktop\python\dmads-env\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 551     data = data[cols]
#     552
#     553     # Initialize the grid
#
# c:\users\zak\desktop\python\dmads-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# c:\users\zak\desktop\python\dmads-env\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# c:\users\zak\desktop\python\dmads-env\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# c:\users\zak\desktop\python\dmads-env\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['Diabetes'] not in index"
